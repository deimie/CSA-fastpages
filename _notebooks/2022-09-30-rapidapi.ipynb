// %% [markdown]
// # Rapid Api
//
// * image: images/rapidapi.png

// %%
import java.net.URI;
import java.net.http.HttpClient;
import java.net.http.HttpRequest;
import java.net.http.HttpResponse;

HttpRequest request = HttpRequest.newBuilder()
		.uri(URI.create("https://vaccovid-coronavirus-vaccine-and-treatment-tracker.p.rapidapi.com/api/npm-covid-data/"))
		.header("X-RapidAPI-Key", "56fbb90d5dmsh03022062645ef2ep1e7dabjsn91f3cf3866a7")
		.header("X-RapidAPI-Host", "vaccovid-coronavirus-vaccine-and-treatment-tracker.p.rapidapi.com")
		.method("GET", HttpRequest.BodyPublishers.noBody())
		.build();
HttpResponse<String> response = HttpClient.newHttpClient().send(request, HttpResponse.BodyHandlers.ofString());
System.out.println(response.body());
// Out:
// [{"id":"40f44943-8413-4a31-a4df-deee8111f85f","rank":0,"Country":"World","Continent":"All","TwoLetterSymbol":null,"ThreeLetterSymbol":null,"Infection_Risk":0,"Case_Fatality_Rate":1.05,"Test_Percentage":0,"Recovery_Proporation":96.76,"TotalCases":622629345,"NewCases":243115,"TotalDeaths":6547878,"NewDeaths":592,"TotalRecovered":"602470524","NewRecovered":312900,"ActiveCases":13610943,"TotalTests":"0","Population":"0","one_Caseevery_X_ppl":0,"one_Deathevery_X_ppl":0,"one_Testevery_X_ppl":0,"Deaths_1M_pop":840,"Serious_Critical":39673,"Tests_1M_Pop":0,"TotCases_1M_Pop":79878},{"id":"63492a0f-56d7-4c00-9ac1-d64fd5414029","rank":0,"Country":"Total:","Continent":"All","TwoLetterSymbol":null,"ThreeLetterSymbol":null,"Infection_Risk":0,"Case_Fatality_Rate":1.05,"Test_Percentage":0,"Recovery_Proporation":96.76,"TotalCases":622629345,"NewCases":243115,"TotalDeaths":6547878,"NewDeaths":592,"TotalRecovered":"602470524","NewRecovered":312900,"ActiveCases":13610943,"TotalTests":"0","Population":"0","one_Caseevery_X_ppl":0,"one_Deathevery_X_ppl":0,"one_Testevery_X_ppl":0,"Deaths_1M_pop":840,"Serious_Critical":39673,"Tests_1M_Pop":0,"TotCases_1M_Pop":79877.5},{"id":"be02608d-a52f-4586-ae9b-220dee7daaf1","rank":1,"Country":"USA","Continent":"North America","TwoLetterSymbol":"us","ThreeLetterSymbol":"usa","Infection_Risk":29.3,"Case_Fatality_Rate":1.1,"Test_Percentage":333.71,"Recovery_Proporation":96.74,"TotalCases":98166904,"NewCases":0,"TotalDeaths":1084282,"NewDeaths":0,"TotalRecovered":"94962112","NewRecovered":0,"ActiveCases":2120510,"TotalTests":"1118158870","Population":"335064920","one_Caseevery_X_ppl":3,"one_Deathevery_X_ppl":309,"one_Testevery_X_ppl":0,"Deaths_1M_pop":3236,"Serious_Critical":2970,"Tests_1M_Pop":3337141,"TotCases_1M_Pop":292979},{"id":"f6ecf8d7-5867-42dc-9290-24fda4cb14f0","rank":2,"Country":"India","Continent":"Asia","TwoLetterSymbol":"in","ThreeLetterSymbol":"ind","Infection_Risk":3.16,"Case_Fatality_Rate":1.19,"Test_Percentage":63.42,"Recovery_Proporation":98.73,"TotalCases":44587307,"NewCases":0,"TotalDeaths":528629,"NewDeaths":0,"TotalRecovered":"44019095","NewRecovered":0,"ActiveCases":39583,"TotalTests":"894416853","Population":"1410384595","one_Caseevery_X_ppl":32,"one_Deathevery_X_ppl":2668,"one_Testevery_X_ppl":2,"Deaths_1M_pop":375,"Serious_Critical":698,"Tests_1M_Pop":634165,"TotCases_1M_Pop":31614},{"id":"911f9162-c39d-4e1c-9768-4d147cce2604","rank":3,"Country":"France","Continent":"Europe","TwoLetterSymbol":"fr","ThreeLetterSymbol":"fra","Infection_Risk":53.88,"Case_Fatality_Rate":0.44,"Test_Percentage":413.88,"Recovery_Proporation":97.69,"TotalCases":35342950,"NewCases":0,"TotalDeaths":155078,"NewDeaths":0,"TotalRecovered":"34527115","NewRecovered":0,"ActiveCases":660757,"TotalTests":"271490188","Population":"65596804","one_Caseevery_X_ppl":2,"one_Deathevery_X_ppl":423,"one_Testevery_X_ppl":0,"Deaths_1M_pop":2364,"Serious_Critical":869,"Tests_1M_Pop":4138772,"TotCases_1M_Pop":538791},{"id":"338a3103-483a-4292-9559-1aac2ed47a90","rank":4,"Country":"Brazil","Continent":"South America","TwoLetterSymbol":"br","ThreeLetterSymbol":"bra","Infection_Risk":16.07,"Case_Fatality_Rate":1.98,"Test_Percentage":29.53,"Recovery_Proporation":97.5,"TotalCases":34706757,"NewCases":0,"TotalDeaths":686027,"NewDeaths":0,"TotalRecovered":"33838636","NewRecovered":0,"ActiveCases":182094,"TotalTests":"63776166","Population":"215942339","one_Caseevery_X_ppl":6,"one_Deathevery_X_ppl":315,"one_Testevery_X_ppl":3,"Deaths_1M_pop":3177,"Serious_Critical":8318,"Tests_1M_Pop":295339,"TotCases_1M_Pop":160722},{"id":"4be614b7-9865-4e78-a841-7dca20abd314","rank":5,"Country":"Germany","Continent":"Europe","TwoLetterSymbol":"de","ThreeLetterSymbol":"deu","Infection_Risk":39.48,"Case_Fatality_Rate":0.45,"Test_Percentage":144.97,"Recovery_Proporation":97.01,"TotalCases":33312373,"NewCases":0,"TotalDeaths":149948,"NewDeaths":0,"TotalRecovered":"32315200","NewRecovered":31000,"ActiveCases":847225,"TotalTests":"122332384","Population":"84383629" ...
